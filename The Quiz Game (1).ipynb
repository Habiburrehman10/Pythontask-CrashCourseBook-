# %%
Start=input("Do you want to play the Quiz Game? Press Y/N : ").upper()

if Start == "Y":
    def Quiz_game():
        score=0
        print("""         
                         WELCOME TO QUIZ GAME          
                    There are total of Five question 
                 and you will marked from 100 in percent

    Here are the questions :        """)
        print(" ")
        Q1=input("what is 2 + 2 ?")
        if Q1 == "4":
            print("Correct Answer! Welldone")
            score  += 20
        else:
            print("Wrong Answer!")
        Q2=input("what is 4*4 ?")
        if Q2 == "16":
            print("Correct Answer! Welldone")
            score  += 20
        else:
            print("Wrong Answer!")
        Q3=input("what is (2+2)*2 ?")
        if Q3 == "8":
            print("Correct Answer! Welldone")
            score  += 20
        else:
            print("Wrong Answer!")
        Q4=input("what is 4+4 ?")
        if Q4 == "8":
            print("Correct Answer! Welldone")
            score  += 20
        else:
            print("Wrong Answer!")
        Q5=input("what is 25+12 ?")
        if Q5 == "37":
            print("Correct Answer! Welldone")
            score  += 20
        else:
            print("Wrong Answer!")
        print(" ")
        print(f"you got {score}% marks in your Quiz.")
        print(" ")
        Start1=input("Do you want to play again? Y/N : ").upper()
        if Start1 == "Y":
            Quiz_game()
        else:
            print(" ")
            print("Thanks for playing our quiz game")
    Quiz_game()
            

        

    
        
        
    
elif Start == "N":
    print("Thanks for your response")
# Out:
# Do you want to play the Quiz Game? Press Y/N : y
#
#                          WELCOME TO QUIZ GAME
#                     There are total of Five question
#                  and you will marked from 100 in percent
#
#     Here are the questions :
#
# what is 2 + 2 ?4
# Correct Answer! Welldone
# what is 4*4 ?8
# Wrong Answer!
# what is (2+2)*2 ?8
# Correct Answer! Welldone
# what is 4+4 ?8
# Correct Answer! Welldone
# what is 25+12 ?8
# Wrong Answer!
#
# you got 60% marks in your Quiz.
#
# Do you want to play again? Y/N : n
#
# Thanks for playing our quiz game
